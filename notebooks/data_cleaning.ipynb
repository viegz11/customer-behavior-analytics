# %%
import pandas as pd
import numpy as np

df = pd.read_excel("../data/raw/online_retail.xlsx")

# %%
df_clean = df.copy()
df_clean.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      2928
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    107927
# Country             0
# dtype: int64

# %%
df_clean = df_clean.dropna(subset=['Customer ID'])
df_clean = df_clean.dropna(subset=['Description'])

# %%
df_clean.duplicated().sum()
df_clean = df_clean.drop_duplicates()

# %%
df_clean[df_clean['Quantity'] < 0].head()
df_clean = df_clean[df_clean['Quantity'] > 0]

# %%
df_clean = df_clean[df_clean['Price'] > 0]

# %%
df_clean['Customer ID'] = df_clean['Customer ID'].astype(str)
df_clean['Revenue'] = df_clean['Quantity'] * df_clean['Price']

# %%
df_clean['Year'] = df_clean['InvoiceDate'].dt.year
df_clean['Month'] = df_clean['InvoiceDate'].dt.month
df_clean['Day'] = df_clean['InvoiceDate'].dt.day

# %%
df_clean.info()
df_clean.describe()
df_clean.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# Index: 400916 entries, 0 to 525460
# Data columns (total 12 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      400916 non-null  object
#  1   StockCode    400916 non-null  object
#  2   Description  400916 non-null  object
#  3   Quantity     400916 non-null  int64
#  4   InvoiceDate  400916 non-null  datetime64[us]
#  5   Price        400916 non-null  float64
#  6   Customer ID  400916 non-null  str
#  7   Country      400916 non-null  str
#  8   Revenue      400916 non-null  float64
#  9   Year         400916 non-null  int32
#  10  Month        400916 non-null  int32
#  11  Day          400916 non-null  int32
# dtypes: datetime64[us](1), float64(2), int32(3), int64(1), object(3), str(2)
# memory usage: 35.2+ MB
# Invoice        0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# Price          0
# Customer ID    0
# Country        0
# Revenue        0
# Year           0
# Month          0
# Day            0
# dtype: int64

# %%
df_clean.to_csv("../data/cleaned/cleaned_online_retail.csv", index=False)
